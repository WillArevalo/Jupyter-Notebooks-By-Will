# %%
from IPython.display import display
from IPython.display import Image as _Imgdis
from PIL import Image
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os,glob

from os import listdir,makedirs

from os.path import isfile,join

# %%
# %%time
folder = "Pool_Imgs/"

onlyfiles = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]

print("Working with {0} images".format(len(onlyfiles)))
print("Image examples: ")

for i in range(40, 42):
    print(onlyfiles[i])
    display(_Imgdis(filename=folder + "/" + onlyfiles[i], width=256, height=256))
# Out:
# Working with 112120 images
# Image examples:
# 00001326_005.png
# 00010331_002.png
# CPU times: user 362 ms, sys: 145 ms, total: 507 ms
# Wall time: 560 ms

# %%
from scipy import ndimage
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

train_files = []

y_train = []
i=0
for _file in onlyfiles:
    train_files.append(_file)
    label_in_file = _file.find("_")
    y_train.append(int(_file[0:label_in_file]))
    
print("Files in train_files: %d" % len(train_files))

# Original Dimensions
image_width = 256
image_height = 256
ratio = 1

image_width = int(image_width / ratio)
image_height = int(image_height / ratio)

channels = 1
nb_classes = 1
np.ndarray?
dataset = np.ndarray(shape=(len(train_files), channels, image_height, image_width),dtype=np.float32)

i = 0
for _file in train_files:
    #img = load_img(folder + "/" + _file)  # this is a PIL image
    #img.thumbnail((image_width, image_height))
    
    
    pil_im = Image.open(folder + "/" + _file)
    pil_imgray = pil_im.convert('LA')

    img = np.array(list(pil_imgray.getdata(band=0)), float)
    img.shape = (pil_imgray.size[1], pil_imgray.size[0])
    if i == 2:
        plt.imshow(img)
    
    # Convert to Numpy Array
    #x = img_to_array(img)  
    # x = x.reshape((1, 256, 256))
    # Normalize
    # x = (x - 128.0) / 128.0
    dataset[i] = img
    i += 1
    if i % 250 == 0:
        print("%d images to array" % i)
print("All images to array!")
# Out:
# Files in train_files: 112120
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-6-07c226f7bf07> in <module>()
#      26 nb_classes = 1
#      27 get_ipython().run_line_magic('pinfo', 'np.ndarray')
# ---> 28 dataset = np.ndarray(shape=(len(train_files), channels, image_height, image_width),dtype=np.float32)
#      29
#      30 i = 0
#
# MemoryError:

# %%
dataset.shape
# Out:
# (4999, 1, 256, 256)

# %% [markdown]
# https://www.kaggle.com/lgmoneda/from-image-files-to-numpy-arrays

# %%
np.save('datasetimg.npy', dataset)

# %% [markdown]
# https://stackoverflow.com/questions/28439701/how-to-save-and-load-numpy-array-data-properly

# %%
dataset = np.ndarray(shape=(112120, 1, 256, 256),dtype=np.float32)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-60698eda35c3> in <module>()
# ----> 1 dataset = np.ndarray(shape=(112120, 1, 256, 256),dtype=np.float32)
#
# MemoryError:
